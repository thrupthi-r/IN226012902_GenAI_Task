# %%
# Task 1: Conceptual Understanding.


#1. What is the difference between "Love" and "love" in NLP?
  # In NLP, "Love" and "love" are treated as different tokens Because computers are case-sensitive 
  # So we convert everything to lowercase to avoid duplication.

#2. What happens if stopwords are not removed?
 # Stopwords is like common words ex(is, the, and, etc.) If Stopwords are not removed the Model becomes noisy ,
 # More computation and  Less meaningful insights.

#3. Provide two real-world scenarios where removing stopwords can be harmful.
 # Removing stopwords can be harmful because it often destroys the logical intent and semantic meaning of a sentence.
 # In sentiment analysis, removing negations like "not" or "never" completely reverses the message, leading to incorrect conclusions.
 # Furthermore, in question-answering systems, removing words like "who," "what," or "how" strips away the specific information the user is seeking, 
 # turning a structured query into a vague list of keywords that lacks context.

#4. Explain the difference between stemming and lemmatization.
 # Stemming: is a fast, rule-based process that "chops off" the ends of words to find a common root, often resulting in non-dictionary words.
 # Lemmatization is a more sophisticated, dictionary-based approach that considers the context and part of speech to return the actual linguistically
 # correct root, or lemma

# %%
# Task 2:Build Advanced Preprocessing Function.

import re
def preprocess_text(text):
    if not text or text.strip() == "":
        return [], ""
    text = text.lower()
    text = re.sub(r"http\S+|www\S+", "", text)
    text = re.sub(r"\S+@\S+", "", text)
    text = re.sub(r"\d+", "", text)
    text = re.sub(r"(.)\1{2,}", r"\1\1", text)
    text = re.sub(r"[^\w\s]", "", text)
    text = re.sub(r"\s+", " ", text).strip()
    tokens = text.split()
    important_words = {"no", "not"}
    tokens = [word for word in tokens if len(word) > 2 or word in important_words]
    clean_sentence = " ".join(tokens)
    return tokens, clean_sentence

# %%
# Task 3: Stress Testing.

sample_inputs = [
    "Get 100% FREE access now!!!",
    "I absolutely looooved this product 😍😍",
    "Worst service ever... 0/10",
    "Call me at 9876543210",
    "This is THE best course!!!",
    "Visit https://openai.com now!",
    "Nooooo this is baaad!!!",
    "OK OK OK I got it",
    "Win $$$ now!!! Limited offer!!!",
    "I am not happy with this"
]
for text in sample_inputs:
    tokens, clean = preprocess_text(text)
    print("Original:", text)
    print("Tokens:", tokens)
    print("Clean:", clean)
    print("-"*50)
# Out:
# Original: Get 100% FREE access now!!!
# Tokens: ['get', 'free', 'access', 'now']
# Clean: get free access now
# --------------------------------------------------
# Original: I absolutely looooved this product 😍😍
# Tokens: ['absolutely', 'looved', 'this', 'product']
# Clean: absolutely looved this product
# --------------------------------------------------
# Original: Worst service ever... 0/10
# Tokens: ['worst', 'service', 'ever']
# Clean: worst service ever
# --------------------------------------------------
# Original: Call me at 9876543210
# Tokens: ['call']
# Clean: call
# --------------------------------------------------
# Original: This is THE best course!!!
# Tokens: ['this', 'the', 'best', 'course']
# Clean: this the best course
# --------------------------------------------------
# Original: Visit https://openai.com now!
# Tokens: ['visit', 'now']
# Clean: visit now
# --------------------------------------------------
# Original: Nooooo this is baaad!!!
# ...

# %%
# Task 4: Token Analytics.

for text in sample_inputs:
    tokens, _ = preprocess_text(text)
    total, unique, avg = analyze_tokens(tokens)
    print(text)
    print("Total:", total, "Unique:", unique, "Avg Length:", avg)
    print()
# Out:
# Get 100% FREE access now!!!
# Total: 4 Unique: 4 Avg Length: 4.0
#
# I absolutely looooved this product 😍😍
# Total: 4 Unique: 4 Avg Length: 6.75
#
# Worst service ever... 0/10
# Total: 3 Unique: 3 Avg Length: 5.333333333333333
#
# Call me at 9876543210
# Total: 1 Unique: 1 Avg Length: 4.0
#
# This is THE best course!!!
# Total: 4 Unique: 4 Avg Length: 4.25
#
# Visit https://openai.com now!
# Total: 2 Unique: 2 Avg Length: 4.0
#
# Nooooo this is baaad!!!
# Total: 3 Unique: 3 Avg Length: 3.6666666666666665
#
# OK OK OK I got it
# Total: 1 Unique: 1 Avg Length: 3.0
#
# Win $$$ now!!! Limited offer!!!
# Total: 4 Unique: 4 Avg Length: 4.5
#
# I am not happy with this
# Total: 4 Unique: 4 Avg Length: 4.0

# %%
# Task 5: Frequency Analysis.

from collections import Counter
all_tokens = []
for text in sample_inputs:
    tokens, _ = preprocess_text(text)
    all_tokens.extend(tokens)
counter = Counter(all_tokens)
print("Top 10 most common:", counter.most_common(10))
print("Least 5 common:", counter.most_common()[-5:])
# Out:
# Top 10 most common: [('this', 4), ('now', 3), ('get', 1), ('free', 1), ('access', 1), ('absolutely', 1), ('looved', 1), ('product', 1), ('worst', 1), ('service', 1)]
# Least 5 common: [('limited', 1), ('offer', 1), ('not', 1), ('happy', 1), ('with', 1)]

# %%
# Task 6: Build Full Pipeline.

def full_pipeline(text_list):
    all_tokens = []
    clean_sentences = []
    
    for text in text_list:
        tokens, clean_sentence = preprocess_text(text)
        all_tokens.extend(tokens)
        clean_sentences.append(clean_sentence)
    return {
        "tokens": all_tokens,
        "clean_sentences": clean_sentences
    }
result = full_pipeline(sample_inputs)
print("All Tokens:")
print(result["tokens"])
print("\nClean Sentences:")
for sentence in result["clean_sentences"]:
    print(sentence)
# Out:
# All Tokens:
# ['get', 'free', 'access', 'now', 'absolutely', 'looved', 'this', 'product', 'worst', 'service', 'ever', 'call', 'this', 'the', 'best', 'course', 'visit', 'now', 'noo', 'this', 'baad', 'got', 'win', 'now', 'limited', 'offer', 'not', 'happy', 'with', 'this']
#
# Clean Sentences:
# get free access now
# absolutely looved this product
# worst service ever
# call
# this the best course
# visit now
# noo this baad
# got
# win now limited offer
# not happy with this
